# %% [markdown]
# #1

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls 'drive/My Drive'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2630604/3243939291.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3 get_ipython().system("ls 'drive/My Drive'")
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !ls 'drive/My Drive/BraTS2019'
# Out:
# 3d-mri-brain-tumor-segmentation-using-autoencoder-regularization-master
# MICCAI_BraTS_2019_Data_Training.zip
# MICCAI_BraTS_2019_Data_Validation.zip

# %%
# !unzip 'drive/My Drive/BraTS2019/MICCAI_BraTS_2019_Data_Training.zip' -d 'Data/train/'

# %%
# !pip install SimpleITK

# %%
import SimpleITK as sitk  # For loading the dataset
def ri(img_path):
  return sitk.GetArrayFromImage(sitk.ReadImage(img_path))

# %%
import glob as glob
xl=[]
fl=[]
for f in sorted(glob.glob('Data/train/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_10_1/*')):
  x=ri(f)
  fl.append(f)
  xl.append(x)

num=100
import matplotlib.pyplot as plt
fig=plt.figure(1,figsize=(5,10))
plt.set_cmap('gray')
for i in range(len(xl)):
  fig.add_subplot(len(xl),1,i+1)
  plt.imshow(xl[i][100])

# %% [markdown]
# #2

# %% [markdown]
# ##1

# %%
# !apt install unrar
# !pip install rarfile
import rarfile as rarfile
zip_ref = rarfile.RarFile('drive/My Drive/1123856_New_folder__2_.rar', 'r')
zip_ref.extractall('Data')
zip_ref.close()

from IPython.display import clear_output
clear_output()

# %%
# !mv 'Data/New folder (2)/label/35label/ADNI_002_S_0685_18211' 'Data/New folder (2)/label/35label/ADNI_002_S_0685_18211_tal_noscale'
# !ls 'Data/New folder (2)/label/35label/ADNI_002_S_0685_18211_tal_noscale'
# Out:
# ADNI_002_S_0685_18211_L  ADNI_002_S_0685_18211_R

# %%
import numpy as np
from IPython.display import clear_output
import os
import glob as glob
import matplotlib.pyplot as plt
from skimage.transform import resize

ld=[]
ress=192,128
dl=sorted(os.listdir('Data/New folder (2)/label/35label'))
c=0
for dli in dl:
  c+=1
  dll=sorted(os.listdir('Data/New folder (2)/label/35label/'+dli))
  lld=[]
  fll=sorted(glob.glob('Data/New folder (2)/label/35label/'+dli+'/'+dll[0]+'/*jpg'))[50:114]
  flr=sorted(glob.glob('Data/New folder (2)/label/35label/'+dli+'/'+dll[1]+'/*jpg'))[50:114]
  for i in range(len(fll)):
    a=plt.imread(fll[i])
    b=plt.imread(flr[i])
    x=a+b
    x=resize(x, ress)
    x=x[:,:,0]
    lld.append(x)
  ld.append(lld)
  clear_output()
  print(c)
# Out:
# 35

# %%
l35=np.array(ld)
l35.shape
# Out:
# (35, 64, 192, 128)

# %%
import pickle as pkl
pkl.dump(l35, open( "drive/My Drive/Mahsa/35l.p", "wb" ))

# %%
import numpy as np
from IPython.display import clear_output
import os
import glob as glob
import matplotlib.pyplot as plt
from skimage.transform import resize

ld=[]
dl=sorted(os.listdir('Data/New folder (2)/label/100label'))
c=0
for dli in dl:
  c+=1
  dll=sorted(os.listdir('Data/New folder (2)/label/100label/'+dli))
  lld=[]
  fll=sorted(glob.glob('Data/New folder (2)/label/100label/'+dli+'/'+dll[0]+'/*jpg'))[50:114]
  if c!=43:
    flr=sorted(glob.glob('Data/New folder (2)/label/100label/'+dli+'/'+dll[1]+'/*jpg'))[50:114]
  for i in range(len(fll)):
    a=plt.imread(fll[i])
    b=plt.imread(flr[i])
    x=a+b
    x=resize(x, ress)
    x=x[:,:,0]
    lld.append(x)
  if c!=43:
    ld.append(lld)
  clear_output()
  print(c)
# Out:
# 100

# %%
l100=np.array(ld)
l100.shape
# Out:
# (99, 64, 192, 128)

# %%
import pickle as pkl
pkl.dump(l100, open( "drive/My Drive/Mahsa/100l.p", "wb" ))

# %%
import numpy as np
from IPython.display import clear_output
import os
import glob as glob
import matplotlib.pyplot as plt
from skimage.transform import resize

ld=[]
dl=sorted(os.listdir('Data/New folder (2)/original/35/35/'))
c=0
for dli in dl:
  c+=1
  lld=[]
  fl=sorted(glob.glob('Data/New folder (2)/original/35/35/'+dli+'/'+'/*jpg'))[50:114]
  for i in range(len(fl)):
    x=plt.imread(fl[i])
    x=resize(x, ress)
    x=x[:,:,0]
    lld.append(x)
  ld.append(lld)
  clear_output()
  print(c)
# Out:
# 35

# %%
i35=np.array(ld)
i35.shape
# Out:
# (35, 64, 192, 128)

# %%
import pickle as pkl
pkl.dump(i35, open( "drive/My Drive/Mahsa/35i.p", "wb" ))

# %%
import numpy as np
from IPython.display import clear_output
import os
import glob as glob
import matplotlib.pyplot as plt
from skimage.transform import resize

ld=[]
dl=sorted(os.listdir('Data/New folder (2)/original/100/'))
c=0
for dli in dl:
  c+=1
  lld=[]
  if c!=43:
    fl=sorted(glob.glob('Data/New folder (2)/original/100/'+dli+'/*jpg'))[50:114]
  for i in range(len(fl)):
    x=plt.imread(fl[i])
    x=resize(x, ress)
    x=x[:,:,0]
    lld.append(x)
  if c!=43:
    ld.append(lld)
  clear_output()
  print(c)

# %%
i100=np.array(ld)
i100.shape
# Out:
# (99, 64, 192, 128)

# %%
import pickle as pkl
pkl.dump(i100, open( "drive/My Drive/Mahsa/100i.p", "wb" ))

# %%
# %reset
import pickle as pkl
i100=pkl.load(open( "drive/My Drive/Mahsa/100i.p", "rb" ))
l100=pkl.load(open( "drive/My Drive/Mahsa/100l.p", "rb" ))

l100[l100 >= 0.1] = 1
l100[l100 < 0.1]= 0

pkl.dump((i100,l100),open( "drive/My Drive/Mahsa/MRISEG-tr", "wb" ))
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?
# Nothing done.

# %%
# %reset
import pickle as pkl
i35=pkl.load(open( "drive/My Drive/Mahsa/35i.p", "rb" ))
l35=pkl.load(open( "drive/My Drive/Mahsa/35l.p", "rb" ))

l35[l35 >= 0.1] = 1
l35[l35 < 0.1]= 0

pkl.dump((i35,l35),open( "drive/My Drive/Mahsa/MRISEG-te", "wb" ))
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %reset

import pickle as pkl
(xtr,ytr)=pkl.load(open( "drive/My Drive/Mahsa/MRISEG-tr", "rb" ))
(xte,yte)=pkl.load(open( "drive/My Drive/Mahsa/MRISEG-te", "rb" ))

ress=192,128

xtr = xtr.reshape(xtr.shape[0], xtr.shape[1], xtr.shape[2], xtr.shape[3], 1)
ytr = ytr.reshape(ytr.shape[0], ytr.shape[1], ytr.shape[2], ytr.shape[3], 1)
xte = xte.reshape(xte.shape[0], xte.shape[1], xte.shape[2], xte.shape[3], 1)
yte = yte.reshape(yte.shape[0], yte.shape[1], yte.shape[2], yte.shape[3], 1)

print(xtr.shape)
print(ytr.shape)
print(xte.shape)
print(yte.shape)
# Out:
# (99, 64, 192, 128, 1)
# (99, 64, 192, 128, 1)
# (35, 64, 192, 128, 1)
# (35, 64, 192, 128, 1)

# %%
num=30
x=xte[num,25,:,:,0]
y=yte[num,25,:,:,0]


import matplotlib.pyplot as plt
fig=plt.figure(1,figsize=(10,10))
plt.set_cmap('gray')
fig.add_subplot(1,2,1)
plt.imshow(x+x+x)
fig.add_subplot(1,2,2)
plt.imshow(x+y+y)

# %% [markdown]
# ##2

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls 'drive/My Drive'
import pickle as pkl
(xtr,ytr),(xte,yte)=pkl.load(open( "drive/My Drive/Mahsa/MRISEG.pkl", "rb" ))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %reset
import numpy as np
import os
import skimage.io as io
import skimage.transform as trans
import numpy as np
import tensorflow
import tensorflow.keras.backend as K
from tensorflow.keras import backend as keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as keras
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.losses import *

import warnings
warnings.filterwarnings("ignore")

################################

################################

# tensorflow.reset_default_graph()


pretrained_weights = None

def dloss(y_true, y_pred):
  numerator = 2 * tensorflow.reduce_sum(y_true * y_pred, axis=(1,2,3))
  denominator = tensorflow.reduce_sum(y_true + y_pred, axis=(1,2,3))

  return 1 - numerator / denominator

def closs(y_true, y_pred):
    def dice_loss(y_true, y_pred):
        numerator = 2 * tensorflow.reduce_sum(y_true * y_pred, axis=(1,2,3))
        denominator = tensorflow.reduce_sum(y_true + y_pred, axis=(1,2,3))

        return K.reshape(1 - numerator / denominator, (-1, 1, 1))

    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def iou_loss_core(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return 1-iou
  
def iou_core(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou 
  

nf=2
input_size = (64,192,128,1)
inputs = Input(input_size)
# inputs=BatchNormalization()(inputs)  
conv1 = Conv3D(nf, 3, padding = 'same', kernel_initializer = 'he_normal')(inputs)
# conv1 = Conv3D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
conv1=BatchNormalization()(conv1)
conv1=LeakyReLU(alpha=0.3)(conv1)
pool1 = MaxPooling3D(pool_size=2)(conv1)
  
conv2 = Conv3D(nf*2, 3, padding = 'same', kernel_initializer = 'he_normal')(pool1)
# conv2 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
conv2=BatchNormalization()(conv2)
conv2=LeakyReLU(alpha=0.3)(conv2)
pool2 = MaxPooling3D(pool_size=2)(conv2)
  
conv3 = Conv3D(nf*4, 3, padding = 'same', kernel_initializer = 'he_normal')(pool2)
# conv3 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
conv3=BatchNormalization()(conv3)
conv3=LeakyReLU(alpha=0.3)(conv3)
pool3 = MaxPooling3D(pool_size=2)(conv3)
  
conv4 = Conv3D(nf*8, 3, padding = 'same', kernel_initializer = 'he_normal')(pool3)
# conv4 = Conv3D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
conv4=LeakyReLU(alpha=0.3)(conv4)
conv4=BatchNormalization()(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling3D(pool_size=(2))(drop4)
conv5 = Conv3D(nf*16, 3, padding = 'same', kernel_initializer = 'he_normal')(pool4)
# conv5 = Conv3D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
conv5=LeakyReLU(alpha=0.3)(conv5)
conv5=BatchNormalization()(conv5)
drop5 = Dropout(0.5)(conv5)
up6 = Conv3D(nf*32, 2, padding = 'same', kernel_initializer = 'he_normal')(UpSampling3D(size = 2)(drop5))
up6=LeakyReLU(alpha=0.3)(up6)
up6=BatchNormalization()(up6)
merge6 = concatenate([drop4,up6], axis = 4)
conv6 = Conv3D(nf*32, 3, padding = 'same', kernel_initializer = 'he_normal')(merge6)
# conv6 = Conv3D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
conv6=LeakyReLU(alpha=0.3)(conv6)
conv6=BatchNormalization()(conv6)

up7 = Conv3D(nf*16, 2, padding = 'same', kernel_initializer = 'he_normal')(UpSampling3D(size = 2)(conv6))
up7=LeakyReLU(alpha=0.3)(up7)
up7=BatchNormalization()(up7)
merge7 = concatenate([conv3,up7], axis = 4)
conv7 = Conv3D(nf*16, 3, padding = 'same', kernel_initializer = 'he_normal')(merge7)
# conv7 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
conv7=LeakyReLU(alpha=0.3)(conv7)
conv7=BatchNormalization()(conv7)
up8 = Conv3D(nf*8, 2, padding = 'same', kernel_initializer = 'he_normal')(UpSampling3D(size = 2)(conv7))
up8=LeakyReLU(alpha=0.3)(up8)
up8=BatchNormalization()(up8)
merge8 = concatenate([conv2,up8], axis = 4)
conv8 = Conv3D(nf*4, 3, padding = 'same', kernel_initializer = 'he_normal')(merge8)
# conv8 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
conv8=LeakyReLU(alpha=0.3)(conv8)
conv8=BatchNormalization()(conv8)

up9 = Conv3D(nf*2, 2, padding = 'same', kernel_initializer = 'he_normal')(UpSampling3D(size = 2)(conv8))
up9=LeakyReLU(alpha=0.3)(up9)
up9=BatchNormalization()(up9)
merge9 = concatenate([conv1,up9], axis = 4)
conv9 = Conv3D(nf*1, 3, padding = 'same', kernel_initializer = 'he_normal')(merge9)
# conv9 = Conv3D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9=LeakyReLU(alpha=0.3)(conv9)
# conv9 = Conv3D(2, 3, padding = 'same', kernel_initializer = 'he_normal')(conv9)
# conv9=LeakyReLU(alpha=0.3)(conv9)
conv9=BatchNormalization()(conv9)

conv10 = Conv3D(1, 1, activation = 'sigmoid')(conv9)

model = Model(inputs = inputs, outputs = conv10)

model.compile(optimizer = Adam(lr = 1e-2), loss = closs, metrics = [iou_core])
    
#model.summary()

if(pretrained_weights):
  model.load_weights(pretrained_weights)

model.fit(xtr,ytr, epochs=10,batch_size=1, validation_data=(xte, yte))
# Out:
# Train on 99 samples, validate on 35 samples
# Epoch 1/10
# 99/99 [==============================] - 41s 418ms/sample - loss: 1.3047 - iou_core: 0.8222 - val_loss: 1.0600 - val_iou_core: 0.9455
# Epoch 2/10
# 99/99 [==============================] - 31s 314ms/sample - loss: 0.9673 - iou_core: 0.9753 - val_loss: 1.7563 - val_iou_core: 0.9707
# Epoch 3/10
# 99/99 [==============================] - 31s 312ms/sample - loss: 0.5287 - iou_core: 0.9984 - val_loss: 1.1443 - val_iou_core: 0.9815
# Epoch 4/10
# 99/99 [==============================] - 31s 313ms/sample - loss: 0.4016 - iou_core: 0.9991 - val_loss: 0.5437 - val_iou_core: 0.9985
# Epoch 5/10
# 99/99 [==============================] - 31s 313ms/sample - loss: 0.3623 - iou_core: 0.9992 - val_loss: 0.7357 - val_iou_core: 0.9961
# Epoch 6/10
# 99/99 [==============================] - 31s 312ms/sample - loss: 0.3357 - iou_core: 0.9993 - val_loss: 0.5727 - val_iou_core: 0.9981
# Epoch 7/10
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# model.save('drive/My Drive/Mahsa/MriSegModel.h5')
import pickle as pkl

(xtr,ytr),(xte,yte)=pkl.load(open( "drive/My Drive/Mahsa/MRISEG.pkl", "rb" ))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
num=15
# z[0][0]=1

import matplotlib.pyplot as plt
fig=plt.figure(1,figsize=(15,200))
plt.set_cmap('gray')
for i in range(30):
  m=i+15
  n=num
  x=xte[num,m,:,:,0]
  y=yte[num,m,:,:,0]
  p = xte[n,:,:,:,0].reshape(1,xte.shape[1], xte.shape[2], xte.shape[3], xte.shape[4])
  z=model.predict(p)
  z=z[0,m,:,:,0]
  fig.add_subplot(30,3,3*i+1)
  plt.imshow(x+x+x)
  fig.add_subplot(30,3,3*i+2)
  plt.imshow(x+y+y)
  fig.add_subplot(30,3,3*i+3)
  plt.imshow(x+z*10)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

from IPython.display import Image
Image(retina=True, filename='model.png')

# %%
# !pip install itk-io
# !pip install itkwidgets
import itk

from itkwidgets import view

try:
    from urllib.request import urlretrieve
except ImportError:
    from urllib import urlretrieve
import os

# %%
# Download data
import os
file_name = '005_32months_T2_RegT1_Reg2Atlas_ManualBrainMask_Stripped.nrrd'
if not os.path.exists(file_name):
    url = 'https://data.kitware.com/api/v1/file/564a5b078d777f7522dbfaa6/download'
    urlretrieve(url, file_name)
image = itk.imread(file_name)
view(image, rotate=True, vmin=4000, vmax=17000, gradient_opacity=0.4)
# Out:
# Viewer(geometries=[], gradient_opacity=0.4, point_sets=[], rendered_image=<itk.itkImagePython.itkImageSS3; pro…

# %%
import pickle as pkl
pkl.dump(xte[15,:,:,:,0], open( "xte15.p", "wb" ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9fca503ad251> in <module>()
#       1 import pickle as pkl
# ----> 2 pkl.dump(xte[15,:,:,:,0], open( "xte15.p", "wb" ))
#
# NameError: name 'xte' is not defined
